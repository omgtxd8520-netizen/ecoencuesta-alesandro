# %% [markdown]
# # Análisis de EcoEncuesta
# Este notebook conecta a la base de datos Postgres y realiza análisis simples.
#
# Requisitos: tener el servicio `db` corriendo y datos en la tabla `surveys`.
